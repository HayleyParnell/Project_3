# %%
from pathlib import Path
from sqlalchemy import create_engine
import pandas as pd
import sqlite3
import json

# %%
path1 = r"Resources/fire_archive_M-C61_423958.csv"
path2 = r"Resources/fire_nrt_M-C61_423958.csv"

# %%
fire_archive = pd.read_csv(path1)
fire_archive.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   19.4050  -155.2786       362.3   1.7    1.3  2014-01-01      1147
# 1   19.4384  -155.0778       352.9   1.7    1.3  2014-01-01      1147
# 2   19.4366  -155.0624       340.5   1.7    1.3  2014-01-01      1147
# 3   19.4030  -155.2622       314.0   1.7    1.3  2014-01-01      1147
# 4   19.4270  -155.0791       314.7   1.7    1.3  2014-01-01      1147
#
#   satellite instrument  confidence  version  bright_t31    frp daynight  type
# 0      Aqua      MODIS         100     6.03       287.3  210.6        N     1
# 1      Aqua      MODIS         100     6.03       294.7  147.6        N     1
# 2      Aqua      MODIS         100     6.03       294.3   95.5        N     1
# 3      Aqua      MODIS          84     6.03       285.3   32.4        N     1
# 4      Aqua      MODIS          86     6.03       288.3   30.0        N     1

# %%
df2 = pd.read_csv(path2)

fire_nrt = pd.DataFrame(df2)
fire_nrt.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  33.41957 -110.86527      337.11  1.28   1.12  2023-02-01       457
# 1  39.01343  -78.35137      302.35  2.09   1.41  2023-02-01      1520
# 2  28.70231  -82.02740      316.50  2.78   1.59  2023-02-01      1522
# 3  26.67987  -80.58160      312.51  2.06   1.40  2023-02-01      1524
# 4  26.98986  -80.41743      312.04  2.02   1.39  2023-02-01      1524
#
#   satellite instrument  confidence version  bright_t31    frp daynight
# 0     Terra      MODIS         100  6.1NRT      277.00  63.34        N
# 1     Terra      MODIS          52  6.1NRT      275.11  26.65        D
# 2     Terra      MODIS          66  6.1NRT      294.86  47.93        D
# 3     Terra      MODIS          48  6.1NRT      295.06  14.41        D
# 4     Terra      MODIS          63  6.1NRT      295.05  18.34        D

# %%
merged_df = pd.concat([fire_archive,fire_nrt],ignore_index=True)
merged_df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   19.4050  -155.2786       362.3   1.7    1.3  2014-01-01      1147
# 1   19.4384  -155.0778       352.9   1.7    1.3  2014-01-01      1147
# 2   19.4366  -155.0624       340.5   1.7    1.3  2014-01-01      1147
# 3   19.4030  -155.2622       314.0   1.7    1.3  2014-01-01      1147
# 4   19.4270  -155.0791       314.7   1.7    1.3  2014-01-01      1147
#
#   satellite instrument  confidence version  bright_t31    frp daynight  type
# 0      Aqua      MODIS         100    6.03       287.3  210.6        N   1.0
# 1      Aqua      MODIS         100    6.03       294.7  147.6        N   1.0
# 2      Aqua      MODIS         100    6.03       294.3   95.5        N   1.0
# 3      Aqua      MODIS          84    6.03       285.3   32.4        N   1.0
# 4      Aqua      MODIS          86    6.03       288.3   30.0        N   1.0

# %%
sampled_df = merged_df.sample(frac=0.3)
sampled_df
# Out:
#          latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 350324    34.0838   -94.6821       311.3   1.2    1.1  2016-11-10      1725
# 48683     40.0281  -114.5989       360.3   2.9    1.6  2014-07-03      1755
# 442555    44.2338  -121.7139       332.5   1.6    1.2  2017-08-20      1843
# 892461    40.6115   -87.6154       300.9   1.1    1.1  2020-11-12      1909
# 663428    38.1802   -96.7038       320.2   1.6    1.2  2019-04-08      1959
# ...           ...        ...         ...   ...    ...         ...       ...
# 908232    31.7732   -95.3704       312.4   1.3    1.1  2021-02-01      1950
# 1091306   32.3819   -98.0326       372.6   1.9    1.3  2022-03-20      2014
# 1156232   48.8237  -114.0870       341.5   1.0    1.0  2022-08-21      2030
# 608696    40.9878  -122.2691       323.8   2.6    1.5  2018-08-21      2037
# 720984    44.3018  -118.4429       328.8   1.8    1.3  2019-09-01      2126
#
#         satellite instrument  confidence version  bright_t31    frp daynight  \
# 350324      Terra      MODIS          71    6.03       292.4   13.5        D
# 48683       Terra      MODIS         100    6.03       306.9  344.9        D
# 442555      Terra      MODIS          66    6.03       293.7   52.6        D
# 892461       Aqua      MODIS          43    6.03       286.4    5.9        D
# 663428       Aqua      MODIS          66    6.03       302.6   15.7        D
# ...           ...        ...         ...     ...         ...    ...      ...
# 908232       Aqua      MODIS          73    6.03       289.0   16.9        D
# 1091306      Aqua      MODIS         100    6.03       309.9  294.6        D
# 1156232      Aqua      MODIS          60    6.03       298.1   43.6        D
# 608696       Aqua      MODIS          74    6.03       295.5   68.4        D
# 720984       Aqua      MODIS          42    6.03       300.3   45.7        D
#
#          type
# 350324    0.0
# 48683     0.0
# 442555    0.0
# 892461    0.0
# 663428    0.0
# ...       ...
# 908232    0.0
# 1091306   0.0
# 1156232   0.0
# 608696    0.0
# 720984    0.0
#
# [387396 rows x 15 columns]

# %%
sampled_df.drop(['scan', 'track','instrument','version'], axis=1, inplace=True)

# %%
sampled_df
# Out:
#          latitude  longitude  brightness    acq_date  acq_time satellite  \
# 350324    34.0838   -94.6821       311.3  2016-11-10      1725     Terra
# 48683     40.0281  -114.5989       360.3  2014-07-03      1755     Terra
# 442555    44.2338  -121.7139       332.5  2017-08-20      1843     Terra
# 892461    40.6115   -87.6154       300.9  2020-11-12      1909      Aqua
# 663428    38.1802   -96.7038       320.2  2019-04-08      1959      Aqua
# ...           ...        ...         ...         ...       ...       ...
# 908232    31.7732   -95.3704       312.4  2021-02-01      1950      Aqua
# 1091306   32.3819   -98.0326       372.6  2022-03-20      2014      Aqua
# 1156232   48.8237  -114.0870       341.5  2022-08-21      2030      Aqua
# 608696    40.9878  -122.2691       323.8  2018-08-21      2037      Aqua
# 720984    44.3018  -118.4429       328.8  2019-09-01      2126      Aqua
#
#          confidence  bright_t31    frp daynight  type
# 350324           71       292.4   13.5        D   0.0
# 48683           100       306.9  344.9        D   0.0
# 442555           66       293.7   52.6        D   0.0
# 892461           43       286.4    5.9        D   0.0
# 663428           66       302.6   15.7        D   0.0
# ...             ...         ...    ...      ...   ...
# 908232           73       289.0   16.9        D   0.0
# 1091306         100       309.9  294.6        D   0.0
# 1156232          60       298.1   43.6        D   0.0
# 608696           74       295.5   68.4        D   0.0
# 720984           42       300.3   45.7        D   0.0
#
# [387396 rows x 11 columns]

# %%
con = sqlite3.connect("fire_db")
sampled_df.to_sql('fire_data',con,if_exists='replace',index=False)
df = pd.read_sql_query("SELECT * from fire_data", con)

# Verify that result of SQL query is stored in the dataframe

# %%
print(df.head())
# Out:
#    latitude  longitude  brightness    acq_date  acq_time satellite  \
# 0   34.0838   -94.6821       311.3  2016-11-10      1725     Terra
# 1   40.0281  -114.5989       360.3  2014-07-03      1755     Terra
# 2   44.2338  -121.7139       332.5  2017-08-20      1843     Terra
# 3   40.6115   -87.6154       300.9  2020-11-12      1909      Aqua
# 4   38.1802   -96.7038       320.2  2019-04-08      1959      Aqua
#
#    confidence  bright_t31    frp daynight  type
# 0          71       292.4   13.5        D   0.0
# 1         100       306.9  344.9        D   0.0
# 2          66       293.7   52.6        D   0.0
# 3          43       286.4    5.9        D   0.0
# 4          66       302.6   15.7        D   0.0

# %%
# json_data = df.to_json(orient='records')
# with open('fire_data.json','w') as f:
#     f.write(json_data)

# %%
# js_file = 'fire_data_js'
# with open(js_file, 'w') as f:
#     f.write(json_data)

# %%
con.close()
